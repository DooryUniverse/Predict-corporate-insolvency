# %% [markdown]
# ### 샤피로 윌크 정규성 검정

# %%
import pandas as pd
from scipy import stats
df = pd.read_csv("../datasets/최종통합데이터(0703).csv", encoding="CP949")
df.drop(['거래소코드', '회계년도', '회사명'], axis=1, inplace=True)
# df.fillna(0, inplace=True)

dff=['이자수익', '당기순이익', '지분법손실', '당좌비율', '매입채무', '이자비용', '영업이익률', '매출채권','영업이익','ROE', 
     '재무활동으로 인한 현금흐름', '현금순환주기', '자기자본비율',"기사단어개수","유사도"]
# a=df.columns.tolist()
# print(a)
for i in dff:   
    df[i]=df[i].astype(float) 
    print(stats.shapiro(df[i]))
# Out:
# ShapiroResult(statistic=0.5842161774635315, pvalue=0.0)
# ShapiroResult(statistic=0.849440336227417, pvalue=0.0)
# ShapiroResult(statistic=0.33783555030822754, pvalue=0.0)
# ShapiroResult(statistic=0.6389977931976318, pvalue=0.0)
# ShapiroResult(statistic=0.5310338735580444, pvalue=0.0)
# ShapiroResult(statistic=0.5811903476715088, pvalue=0.0)
# ShapiroResult(statistic=0.5688838958740234, pvalue=0.0)
# ShapiroResult(statistic=0.581028938293457, pvalue=0.0)
# ShapiroResult(statistic=0.7409192323684692, pvalue=0.0)
# ShapiroResult(statistic=0.3840397000312805, pvalue=0.0)
# ShapiroResult(statistic=0.7579337358474731, pvalue=0.0)
# ShapiroResult(statistic=0.6097350716590881, pvalue=0.0)
# ShapiroResult(statistic=0.9774314165115356, pvalue=3.5003034340369606e-41)
# ShapiroResult(statistic=0.25602293014526367, pvalue=0.0)
# ShapiroResult(statistic=0.593390166759491, pvalue=0.0)
# ...

# %%
# EDF 정규분포 확인
dff=pd.read_csv("../datasets/부도거리/EDF0627.csv",encoding="CP949")
d=["EDF"]
# a=df.columns.tolist()
# print(a)
for i in b:   
    dff[i]=dff[i].astype(float) 
    print(stats.shapiro(dff[i]))
# Out:
# ShapiroResult(statistic=0.7024327516555786, pvalue=0.0)
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\_morestats.py:1761: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")

# %%
df.columns
# Out:
# Index(['자산', '부채', '자본', '매출액', '매출원가', '매출총이익', '영업이익', '당기순이익', '유동자산',
#        '당좌자산', '재고자산', '유동부채', '비유동부채', '매출채권', '매입채무', '단기차입금', '장기차입금', '사채',
#        '유형자산', '이익잉여금', '이자비용', '영업활동으로 인한 현금흐름', '투자활동으로 인한 현금흐름',
#        '재무활동으로 인한 현금흐름', '이자수익', '법인세비용', '지분법이익', '지분법손실', '자기자본비율', '유동비율',
#        '당좌비율', '부채비율', '차입금의존도', '이자보상배율', '매출총이익률', '영업이익률', '당기순이익률', 'ROA',
#        'ROE', '재고자산회전율', '매출채권회전율', '총자산회전율', '매입채무회전율', '매출액증가율', '유형자산증가율',
#        '총자산증가율', '현금순환주기', '기사단어개수', '유사도', '부도'],
#       dtype='object')

# %%
# %matplotlib inline
import matplotlib.font_manager as fm
from matplotlib import font_manager,rc
# 한글 폰트 설정
font_location = r'C:\Windows\Fonts\Gulim.ttc' #굴림
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
# 설치된 폰트 출력
from scipy.stats import probplot
import matplotlib.pyplot as plt
b=['자산', '부채', '자본', '매출액', '매출원가', '매출총이익', '영업이익', '당기순이익', '유동자산',
       '당좌자산', '재고자산', '유동부채', '비유동부채', '매출채권', '매입채무', '단기차입금', '장기차입금', '사채',
       '유형자산', '이익잉여금', '이자비용', '영업활동으로 인한 현금흐름', '투자활동으로 인한 현금흐름',
       '재무활동으로 인한 현금흐름', '이자수익', '법인세비용', '지분법이익', '지분법손실', '자기자본비율', '유동비율',
       '당좌비율', '부채비율', '차입금의존도', '이자보상배율', '매출총이익률', '영업이익률', '당기순이익률', 'ROA',
       'ROE', '재고자산회전율', '매출채권회전율', '총자산회전율', '매입채무회전율', '매출액증가율', '유형자산증가율',
       '총자산증가율', '현금순환주기', '기사단어개수', '유사도', '부도']
c=[661]
for i in b:
    # plt.rc('font', family='NanumSquare')   
    df[i]=df[i].astype(float) 
    plt.figure()
    probplot(df[i], plot=plt)
    plt.title(i)
    plt.show()

# %%
# EDF QQ-plot
# %matplotlib inline
import matplotlib.font_manager as fm
from matplotlib import font_manager,rc
# 한글 폰트 설정
font_location = r'C:\Windows\Fonts\Gulim.ttc' #굴림
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)
# 설치된 폰트 출력
from scipy.stats import probplot
import matplotlib.pyplot as plt


for i in d:
    # plt.rc('font', family='NanumSquare')   
    dff[i]=dff[i].astype(float) 
    plt.figure()
    probplot(dff[i], plot=plt)
    plt.title(i)
    plt.show()

# %%
import scipy.stats as stats

fig = plt.figure(figsize=(20,20))
ax1 = fig.add_subplot(3, 5, 1)
ax2 = fig.add_subplot(3, 5, 2)
ax3 = fig.add_subplot(3, 5, 3)
ax4 = fig.add_subplot(3, 5, 4)
ax5 = fig.add_subplot(3, 5, 5)
ax6 = fig.add_subplot(3, 5, 6)
ax7 = fig.add_subplot(3, 5, 7)
ax8 = fig.add_subplot(3, 5, 8)
ax9 = fig.add_subplot(3, 5, 9)
ax10 = fig.add_subplot(3, 5, 10)
ax11 = fig.add_subplot(3, 5, 11)
ax12= fig.add_subplot(3, 5, 12)
ax13= fig.add_subplot(3, 5, 13)
ax14 = fig.add_subplot(3, 5, 14)
ax15= fig.add_subplot(3, 5, 15)
# ax16= fig.add_subplot(3, 6, 16)
# ax17= fig.add_subplot(3, 6, 17)
# ax18 = fig.add_subplot(3, 6, 18)

# df[i], plot=plt
stats.probplot(df['이자수익'], plot=ax1)
ax1.set_title('이자수익')
stats.probplot(df['당기순이익'], plot=ax2)
ax2.set_title('당기순이익')
stats.probplot(df['지분법손실'], plot=ax3)
ax3.set_title('지분법손실')
stats.probplot(df['당좌비율'], plot=ax4)
ax4.set_title('당좌비율')
stats.probplot(df['매입채무'], plot=ax5)
ax5.set_title('매입채무')
stats.probplot(df['이자비용'], plot=ax6)
ax6.set_title('이자비용')
stats.probplot(df['영업이익률'], plot=ax7)
ax7.set_title('영업이익률')
stats.probplot(df['매출채권'], plot=ax8)
ax8.set_title('매출채권')
stats.probplot(df['ROE'], plot=ax9)
ax9.set_title('ROE')
stats.probplot(df['재무활동으로 인한 현금흐름'], plot=ax10)
ax10.set_title('재무활동으로 인한 현금흐름')
stats.probplot(df['현금순환주기'], plot=ax11)
ax11.set_title('현금순환주기')
stats.probplot(df['자기자본비율'], plot=ax12)
ax12.set_title('자기자본비율')
stats.probplot(df['영업이익'], plot=ax13)
ax13.set_title('영업이익')
stats.probplot(df['기사단어개수'], plot=ax14)
ax14.set_title('기사단어개수')
stats.probplot(df['유사도'], plot=ax15)
ax15.set_title('유사도')
# stats.probplot(df['유형자산증가율'], plot=ax16)
# ax16.set_title('유형자산증가율')
# stats.probplot(df['총자산증가율'], plot=ax17)
# ax17.set_title('총자산증가율')
# stats.probplot(df['재고자산회전율'], plot=ax18)
# ax18.set_title('재고자산회전율')

# '자기자본비율', '유동비율', '당좌비율', '부채비율', '차입금의존도', '이자보상배율', '매출총이익률', '당기순이익률', 'ROA', 'ROE', '재고자산회전율', 
#    '매출채권회전율', '총자산회전율', '매입채무회전율', '매출액증가율', '영업이익증가율', '유형자산증가율', '총자산증가율'
plt.show()

# %% [markdown]
# ### 다중공선성 확인, corr그래프

# %%
df=pd.read_csv("../datasets/재무데이터/DB최종재무데이터(0702).csv", encoding="cp949")
df=df.iloc[:,3:]
import matplotlib.pyplot as plt 
from matplotlib import font_manager,rc
import seaborn as sns    
font_location = r'C:\Windows\Fonts\Gulim.ttc' #굴림
font_name = font_manager.FontProperties(fname=font_location).get_name()
rc('font',family=font_name)

plt.figure(figsize=(30,30))
sns.heatmap(data = df.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
# 다중공선성 확인
import statsmodels.api as sm
import pandas as pd
import numpy as np
import warnings
import seaborn as sns
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
data= pd.read_csv("../datasets/재무데이터/DB최종재무데이터(0702).csv", encoding="cp949")
data.sort_values(by=["거래소코드","회계년도"], inplace=True)

column_list=['영업이익', '당기순이익', '매입채무', '사채', '이익잉여금', '영업활동으로 인한 현금흐름', '투자활동으로 인한 현금흐름', '이자수익', '지분법손실', '자기자본비율', '유동비율', '당좌비율', '매출총이익률', '영업이익률', 'ROA', '총자산회전율', '현금순환주기']
y=data["부도"]
X = data[column_list]
st = StandardScaler()
X= st.fit_transform(X)
X=pd.DataFrame(X, columns=column_list)
# X=pd.concat([X,y], axis=1)

# df_08_17 = X[data['회계년도'].isin([2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])] #train/test
# df_18_20 = X[data['회계년도'].isin([2018,2019,2020])] #validate
# y = data['부도']
# y_08_17=y[data['회계년도'].isin([2008,2009,2010,2011,2012,2013,2014,2015,2016,2017])] #train/test
# y_18_20 = y[data['회계년도'].isin([2018,2019,2020])]#validate
# X_train=df_08_17
# X_test=df_18_20
# y_train=y_08_17
# y_test =y_18_20

# def get_model1(seed):
    
#     log_reg = sm.Logit(y_train, X_train).fit()
#     return log_reg.fit()


# train, test, result1 = get_model1(3)
# print(result1.summary())
# x= sm.add_constant(X_train)
x = sm.add_constant(X)
logit_mod = sm.Logit(y, x)
logit_res = logit_mod.fit(disp=0)
print(logit_res.summary())
# Out:
#                            Logit Regression Results
# ...
# Dep. Variable:                     부도   No. Observations:                13280
# Model:                          Logit   Df Residuals:                    13262
# Method:                           MLE   Df Model:                           17
# Date:                Sat, 02 Jul 2022   Pseudo R-squ.:                  0.2978
# Time:                        16:55:24   Log-Likelihood:                -1842.8
# converged:                       True   LL-Null:                       -2624.5
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -4.0249      0.080    -50.209      0.000      -4.182      -3.868
# 영업이익              -0.7598      0.113     -6.710      0.000      -0.982      -0.538
# ...

# %%
# 0이탈도 계산
from sklearn.metrics import log_loss

y_hat = logit_res.predict(x)
log_loss(y, y_hat, normalize=False)
# Out:
# 1842.8126654111331

# %%
# 맥파든 결정계수값

mu_null = np.sum(y) / len(y)

y_null = np.ones_like(y) * mu_null
log_loss(y, y_null, normalize=False)
1 - (log_loss(y, y_hat) / log_loss(y, y_null))
# Out:
# 0.2978402345934771

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(
    X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns
vif
# Out:
#     VIF Factor features
# 0     5.109333   자기자본비율
# 1   117.744479     유동비율
# 2   110.068914     당좌비율
# 3     1.224798     부채비율
# 4     1.039572   차입금의존도
# 5     1.009295   이자보상배율
# 6     2.338265   매출총이익률
# 7     4.240107    영업이익률
# 8     4.327117   당기순이익률
# 9     1.168040      ROA
# 10    1.258167      ROE
# 11    1.004861  재고자산회전율
# 12    1.189520  매출채권회전율
# 13    2.431369   총자산회전율
# 14    1.005447  매입채무회전율
# 15    1.012044   매출액증가율
# 16    1.007811  유형자산증가율
# 17    1.001223   총자산증가율
# 18    1.295947   현금순환주기
# 19    1.079830       부도

# %%
def get_model2(seed):
    
    model = sm.OLS.from_formula("부도 ~ +자기자본비율 +유동비율 +당좌비율 +부채비율 +차입금의존도 +이자보상배율 +매출총이익률 +영업이익률 +당기순이익률 +ROA +ROE +재고자산회전율 +매출채권회전율 +총자산회전율 +매입채무회전율 +매출액증가율 +유형자산증가율 +총자산증가율 +현금순환주기", data=train)
    return train, test, model.fit()


train, test, result2 = get_model2(3)
print(result2.summary())
